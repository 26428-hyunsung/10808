# %% [markdown]
# <a href="https://colab.research.google.com/github/26428-hyunsung/10808/blob/main/20260904.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input('이름 :')
b = input('나이 :')
print(a, '님 안녕하세요')
print(20-int(b), '년 후면 20살이시네요!')
# Out:
# 이름 :김현성
# 나이 :17
# 김현성 님 안녕하세요
# 3 년 후면 20살이시네요!

# %%
print(7/3)
print(7//3)
print(7%3)
# Out:
# 2.3333333333333335
# 2
# 1

# %%
sec = int(input('시간을 초 단위로 입력하세요:'))
minutes = sec // 60
seconds = sec % 60
print(f'{minutes}분 {seconds}초')
# Out:
# 시간을 초 단위로 입력하세요:555555
# 9259분 15초

# %%
print('########################################\n')
print(['한양과학기술고등학교 학생증'])
int(input('학번:'))
input('성명:')
input('소속:')
print('\n위 사람은 본 학교의 학생임을 증명')
print('\n#######################################')
# Out:
# ########################################
#
# ['한양과학기술고등학교 학생증']
# 학번:10808
# 성명:김현성
# 소속:스마트 전자과
#
# 위 사람은 본 학교의 학생임을 증명
#
# #######################################
