# %% [markdown]
# <a href="https://colab.research.google.com/github/26428-hyunsung/10808/blob/main/20260916.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = []
b = [10,20,30]
c = [1,2,'hello','hi']
d = [10,2.5,['hello','hi']
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))

# %%
a = [10,20,30,['a','b','c']]
b = [40,50,60,['a','b','c'],1.5,-5]
print(a[0])
print(a[-1])
print(a[3][0])
print(a[3][:2])

# %%
a = [4,2,3]
b = [4,5]
c = [1,2,[3,4]]
print(a + b)
print(a * 3)
print(a < b)
print(len(a))
print(len(c))
print(len(c[2]))

# %%
a = [1,2,3,10,20]
print('원본',a)
a[2] = 4
print('결과1 :',a)
a[3:] = [3,4]
print('결과2 :',a)
a[2:] = [3,4]
print('결과3 :',a)
del a[1]
print('결과4 :',a)
del a[1:]
print('결과5 :',a)
del a

# %%
Ist = [1,2]
Ist.append(3)
print(Ist)
# Out:
# [1, 2, 3]

# %%
Ist.insert(1,'a')
print(Ist)
# Out:
# [1, 'a', 2, 3]

# %%
Ist.extend([4,5])
print(Ist)
# Out:
# ['a', 3, 4, 5, 4, 4, 5]

# %%
Ist.remove(1)
print(Ist)
# Out:
# ['a', 2, 3, 4, 5, 4, 5]

# %%
Ist.pop(1)
print(Ist)
Ist.pop()
print(Ist)
# Out:
# ['a', 3, 4, 5, 4, 5]
# ['a', 3, 4, 5, 4]

# %%
Ist.clear()
print(Ist)
# Out:
# []

# %%
Ist = [40,20,30,50,20]
print(Ist.index(20))
print(Ist.index(20,2))
# Out:
# 1
# 4

# %%
print(Ist.count(20))
print(Ist.count('a'))
# Out:
# 0
# 0

# %%
Ist.sort()
print(Ist)
Ist.sort(reverse = True)
print(Ist)
# Out:
# []
# []

# %%
Ist.reverse()
print(Ist)
Ist.reverse()
print(Ist)
# Out:
# []
# []

# %%
list1 = [1,[2,3],4]
list2 = list1.copy()
print(list1)
print(list2)
list1[0] = 10
list1[1][0] = 20
print(list1)
print(list2)
# Out:
# [1, [2, 3], 4]
# [1, [2, 3], 4]
# [10, [20, 3], 4]
# [1, [20, 3], 4]

# %%
Ist = [0,1,5,9,15,20,25,24,19,14]
a = int(input('11월 평균기온'))
b = int(input('12월 평균기온'))
Ist.extend([a,b])
Ist.sort()
print(Ist[0])
print(Ist[-2])
# Out:
# 11월 평균기온3
# 12월 평균기온1
# 0
# 24
