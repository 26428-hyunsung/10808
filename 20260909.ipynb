# %% [markdown]
# <a href="https://colab.research.google.com/github/26428-hyunsung/10808/blob/main/20260909.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b = 1.5
c = 1 + 2j
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(a + 1,type(a + 1))
print(a/b,type(a/b))
print(a/2,type(a/2))
print(a//2,type(a//2))
# Out:
# 5 <class 'int'>
# 1.5 <class 'float'>
# (1+2j) <class 'complex'>
# 6 <class 'int'>
# 3.3333333333333335 <class 'float'>
# 2.5 <class 'float'>
# 2 <class 'int'>

# %%
a = True
b = False
print(a,type(a))
print(b,type(b))
print(10 < 20,type(10 < 20))
print(20 < 10,type(20 < 10))
# Out:
# True <class 'bool'>
# False <class 'bool'>
# True <class 'bool'>
# False <class 'bool'>

# %%
a = 'Hello'
b = ''
c = 10
d = 0
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
# True
# False
# True
# False

# %%
a = '100'
b = 'Python'
c = 'name is "짱구"'
d = '''name is "코난"'''
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
# Out:
# 100 <class 'str'>
# Python <class 'str'>
# name is "짱구" <class 'str'>
# name is "코난" <class 'str'>

# %%
a = 'hello'
b = 'world'
print(a + b)
print(a * 3)
print(a < b)
print('h' in a)
print('wor' not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
a = 'Hello Python'
print(a[0])
print(a[0])
print(a[-1])
# Out:
# H
# H
# n

# %%
a = 'Hello Python'
print(a[0:5])
print(a[6:])
print(a[:5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# Hello
# Python
# Hello
# Py
# HloPt

# %%
str = 'Python'
str.lower()
# Out:
# 'python'

# %%
a = input('주민등록번호 입력:')
print('연:20' + a[0:2]+'년')
print('월:' + a[2:4]+'월')
print('일:' + a[4:6]+'일')
# Out:
# 주민등록번호 입력:101127
# 연:2010년
# 월:11월
# 일:27일

# %%
a = input('주민등록번호 입력:')
print('연:20' + a[0:2]+'년')
print('월:'+ a[2:4]+'월')
print('일:' +a[4:6]+'일')

# %%
original = input('평문 입력:')
encryption1 = original[::-1]
encryption2 = encryption1.replace('e','3').replace('o','0').replace('l','1')
print('암호문:',encryption2)
# Out:
# 평문 입력:sdfdfalfafadia
# 암호문: aidafaf1afdfds
